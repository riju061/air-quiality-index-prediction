# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Data/Real-Data/Real_Combine.csv')

df.head(10)
# Out:
#       T    TM    Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8   4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7   4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4   2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5   3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9   4.4  1017.3  61.0  1.3  8.7  22.2  200.645833
# 5  16.0  25.2  10.0  1013.2  79.0  0.6  4.8  11.1  285.225000
# 6  13.4  21.0   9.2  1015.1  87.0  0.5  1.5   7.6  236.825000
# 7  14.3  22.6   6.6  1016.3  76.0  0.8  0.4   3.5  276.908333
# 8  12.7  18.9   7.3  1021.2  76.0  1.8  6.1  16.5  108.000000
# 9  11.9  18.9   6.3  1020.1  76.0  1.1  8.3  20.6  107.625000

# %%
df=df.dropna()
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features
X.isnull()
# Out:
#          T     TM     Tm    SLP      H     VV      V     VM
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 726  False  False  False  False  False  False  False  False
# 727  False  False  False  False  False  False  False  False
# 728  False  False  False  False  False  False  False  False
# 729  False  False  False  False  False  False  False  False
# 730  False  False  False  False  False  False  False  False
#
# [730 rows x 8 columns]

# %%
y.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# Name: PM 2.5, Length: 730, dtype: bool

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967276  0.958892 -0.884383 -0.518870  0.622637  0.326067
# TM      0.967276  1.000000  0.896699 -0.829254 -0.599629  0.598479  0.320116
# Tm      0.958892  0.896699  1.000000 -0.909514 -0.315305  0.560299  0.312904
# SLP    -0.884383 -0.829254 -0.909514  1.000000  0.274196 -0.491842 -0.346130
# H      -0.518870 -0.599629 -0.315305  0.274196  1.000000 -0.475279 -0.399079
# VV      0.622637  0.598479  0.560299 -0.491842 -0.475279  1.000000  0.402884
# V       0.326067  0.320116  0.312904 -0.346130 -0.399079  0.402884  1.000000
# VM      0.287138  0.299508  0.259431 -0.299830 -0.370981  0.347493  0.760777
# PM 2.5 -0.628336 -0.569381 -0.669059  0.615615  0.174658 -0.628621 -0.354799
#
#               VM    PM 2.5
# T       0.287138 -0.628336
# TM      0.299508 -0.569381
# Tm      0.259431 -0.669059
# SLP    -0.299830  0.615615
# H      -0.370981  0.174658
# VV      0.347493 -0.628621
# V       0.760777 -0.354799
# VM      1.000000 -0.283695
# PM 2.5 -0.283695  1.000000

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
sns.distplot(y)
plt.show()
# Out:
# C:\ProgramData\Anaconda3_2022.10\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10,epochs = 100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#
#  dense_11 (Dense)            (None, 256)               33024
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 35/35 [==============================] - 1s 10ms/step - loss: 70.8471 - mean_absolute_error: 70.8471 - val_loss: 61.6957 - val_mean_absolute_error: 61.6957
# Epoch 2/100
# 35/35 [==============================] - 0s 5ms/step - loss: 66.8696 - mean_absolute_error: 66.8696 - val_loss: 61.2329 - val_mean_absolute_error: 61.2329
# Epoch 3/100
# 35/35 [==============================] - 0s 5ms/step - loss: 65.9636 - mean_absolute_error: 65.9636 - val_loss: 62.1549 - val_mean_absolute_error: 62.1549
# Epoch 4/100
# 35/35 [==============================] - 0s 5ms/step - loss: 65.2224 - mean_absolute_error: 65.2224 - val_loss: 60.6365 - val_mean_absolute_error: 60.6365
# Epoch 5/100
# 35/35 [==============================] - 0s 5ms/step - loss: 62.8112 - mean_absolute_error: 62.8112 - val_loss: 59.9084 - val_mean_absolute_error: 59.9084
# Epoch 6/100
# 35/35 [==============================] - 0s 5ms/step - loss: 58.7503 - mean_absolute_error: 58.7503 - val_loss: 49.6648 - val_mean_absolute_error: 49.6648
# Epoch 7/100
# 35/35 [==============================] - 0s 6ms/step - loss: 46.8800 - mean_absolute_error: 46.8800 - val_loss: 45.2900 - val_mean_absolute_error: 45.2900
# Epoch 8/100
# 35/35 [==============================] - 0s 6ms/step - loss: 47.1054 - mean_absolute_error: 47.1054 - val_loss: 43.3175 - val_mean_absolute_error: 43.3175
# Epoch 9/100
# 35/35 [==============================] - 0s 6ms/step - loss: 47.3754 - mean_absolute_error: 47.3754 - val_loss: 63.2718 - val_mean_absolute_error: 63.2718
# Epoch 10/100
# 35/35 [==============================] - 0s 8ms/step - loss: 49.0097 - mean_absolute_error: 49.0097 - val_loss: 42.6263 - val_mean_absolute_error: 42.6263
# Epoch 11/100
# 35/35 [==============================] - 0s 8ms/step - loss: 43.8716 - mean_absolute_error: 43.8716 - val_loss: 42.4734 - val_mean_absolute_error: 42.4734
# Epoch 12/100
# 35/35 [==============================] - 0s 6ms/step - loss: 42.9334 - mean_absolute_error: 42.9334 - val_loss: 44.4180 - val_mean_absolute_error: 44.4180
# Epoch 13/100
# 35/35 [==============================] - 0s 6ms/step - loss: 42.9037 - mean_absolute_error: 42.9037 - val_loss: 42.3708 - val_mean_absolute_error: 42.3708
# Epoch 14/100
# 35/35 [==============================] - 0s 7ms/step - loss: 46.2605 - mean_absolute_error: 46.2605 - val_loss: 44.7483 - val_mean_absolute_error: 44.7483
# Epoch 15/100
# 35/35 [==============================] - 0s 8ms/step - loss: 43.1351 - mean_absolute_error: 43.1351 - val_loss: 46.0171 - val_mean_absolute_error: 46.0171
# Epoch 16/100
# 35/35 [==============================] - 0s 7ms/step - loss: 41.2520 - mean_absolute_error: 41.2520 - val_loss: 41.9952 - val_mean_absolute_error: 41.9952
# Epoch 17/100
# 35/35 [==============================] - 0s 8ms/step - loss: 41.1634 - mean_absolute_error: 41.1634 - val_loss: 41.5160 - val_mean_absolute_error: 41.5160
# Epoch 18/100
# 35/35 [==============================] - 0s 8ms/step - loss: 41.9780 - mean_absolute_error: 41.9780 - val_loss: 42.9664 - val_mean_absolute_error: 42.9664
# Epoch 19/100
# 35/35 [==============================] - 0s 6ms/step - loss: 41.0920 - mean_absolute_error: 41.0920 - val_loss: 42.5862 - val_mean_absolute_error: 42.5862
# Epoch 20/100
# 35/35 [==============================] - 0s 7ms/step - loss: 43.0211 - mean_absolute_error: 43.0211 - val_loss: 50.6961 - val_mean_absolute_error: 50.6961
# Epoch 21/100
# 35/35 [==============================] - 0s 8ms/step - loss: 41.2201 - mean_absolute_error: 41.2201 - val_loss: 40.8323 - val_mean_absolute_error: 40.8323
# Epoch 22/100
# 35/35 [==============================] - 0s 8ms/step - loss: 42.4663 - mean_absolute_error: 42.4663 - val_loss: 44.2342 - val_mean_absolute_error: 44.2342
# Epoch 23/100
# 35/35 [==============================] - 0s 7ms/step - loss: 44.4922 - mean_absolute_error: 44.4922 - val_loss: 45.4201 - val_mean_absolute_error: 45.4201
# Epoch 24/100
# 35/35 [==============================] - 0s 8ms/step - loss: 40.6730 - mean_absolute_error: 40.6730 - val_loss: 43.9006 - val_mean_absolute_error: 43.9006
# Epoch 25/100
# 35/35 [==============================] - 0s 5ms/step - loss: 40.4090 - mean_absolute_error: 40.4090 - val_loss: 45.3231 - val_mean_absolute_error: 45.3231
# Epoch 26/100
# 35/35 [==============================] - 0s 6ms/step - loss: 40.6826 - mean_absolute_error: 40.6826 - val_loss: 43.3779 - val_mean_absolute_error: 43.3779
# Epoch 27/100
# 35/35 [==============================] - 0s 6ms/step - loss: 39.9368 - mean_absolute_error: 39.9368 - val_loss: 50.1098 - val_mean_absolute_error: 50.1098
# Epoch 28/100
# 35/35 [==============================] - 0s 6ms/step - loss: 42.2864 - mean_absolute_error: 42.2864 - val_loss: 41.4285 - val_mean_absolute_error: 41.4285
# Epoch 29/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6100 - mean_absolute_error: 39.6100 - val_loss: 42.6594 - val_mean_absolute_error: 42.6594
# Epoch 30/100
# 35/35 [==============================] - 0s 8ms/step - loss: 41.4638 - mean_absolute_error: 41.4638 - val_loss: 40.4052 - val_mean_absolute_error: 40.4052
# Epoch 31/100
# 35/35 [==============================] - 0s 6ms/step - loss: 43.5887 - mean_absolute_error: 43.5887 - val_loss: 52.1021 - val_mean_absolute_error: 52.1021
# Epoch 32/100
# 35/35 [==============================] - 0s 5ms/step - loss: 42.1164 - mean_absolute_error: 42.1164 - val_loss: 53.4969 - val_mean_absolute_error: 53.4969
# Epoch 33/100
# 35/35 [==============================] - 0s 5ms/step - loss: 41.0671 - mean_absolute_error: 41.0671 - val_loss: 39.3296 - val_mean_absolute_error: 39.3296
# Epoch 34/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.2261 - mean_absolute_error: 39.2261 - val_loss: 47.6102 - val_mean_absolute_error: 47.6102
# Epoch 35/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.9780 - mean_absolute_error: 39.9780 - val_loss: 42.1922 - val_mean_absolute_error: 42.1922
# Epoch 36/100
# 35/35 [==============================] - 0s 5ms/step - loss: 40.7474 - mean_absolute_error: 40.7474 - val_loss: 46.0388 - val_mean_absolute_error: 46.0388
# Epoch 37/100
# 35/35 [==============================] - 0s 5ms/step - loss: 41.0696 - mean_absolute_error: 41.0696 - val_loss: 40.8130 - val_mean_absolute_error: 40.8130
# Epoch 38/100
# 35/35 [==============================] - 0s 8ms/step - loss: 39.8873 - mean_absolute_error: 39.8873 - val_loss: 39.3466 - val_mean_absolute_error: 39.3466
# Epoch 39/100
# 35/35 [==============================] - 0s 8ms/step - loss: 37.8375 - mean_absolute_error: 37.8375 - val_loss: 42.2281 - val_mean_absolute_error: 42.2281
# Epoch 40/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.4485 - mean_absolute_error: 38.4485 - val_loss: 42.8292 - val_mean_absolute_error: 42.8292
# Epoch 41/100
# 35/35 [==============================] - 0s 8ms/step - loss: 38.6651 - mean_absolute_error: 38.6651 - val_loss: 40.6908 - val_mean_absolute_error: 40.6908
# Epoch 42/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.9782 - mean_absolute_error: 37.9782 - val_loss: 42.0508 - val_mean_absolute_error: 42.0508
# Epoch 43/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.8438 - mean_absolute_error: 39.8438 - val_loss: 47.3312 - val_mean_absolute_error: 47.3312
# Epoch 44/100
# 35/35 [==============================] - 0s 5ms/step - loss: 42.7016 - mean_absolute_error: 42.7016 - val_loss: 39.4478 - val_mean_absolute_error: 39.4478
# Epoch 45/100
# 35/35 [==============================] - 0s 5ms/step - loss: 41.9177 - mean_absolute_error: 41.9177 - val_loss: 40.7369 - val_mean_absolute_error: 40.7369
# Epoch 46/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6725 - mean_absolute_error: 39.6725 - val_loss: 47.8015 - val_mean_absolute_error: 47.8015
# Epoch 47/100
# 35/35 [==============================] - 0s 6ms/step - loss: 43.4153 - mean_absolute_error: 43.4153 - val_loss: 39.1567 - val_mean_absolute_error: 39.1567
# Epoch 48/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.6689 - mean_absolute_error: 39.6689 - val_loss: 39.5675 - val_mean_absolute_error: 39.5675
# Epoch 49/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.1186 - mean_absolute_error: 37.1186 - val_loss: 40.2677 - val_mean_absolute_error: 40.2677
# Epoch 50/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.4611 - mean_absolute_error: 39.4611 - val_loss: 42.2277 - val_mean_absolute_error: 42.2277
# Epoch 51/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.0053 - mean_absolute_error: 39.0053 - val_loss: 39.3388 - val_mean_absolute_error: 39.3388
# Epoch 52/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.6749 - mean_absolute_error: 38.6749 - val_loss: 39.2058 - val_mean_absolute_error: 39.2058
# Epoch 53/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.3483 - mean_absolute_error: 38.3483 - val_loss: 41.1152 - val_mean_absolute_error: 41.1152
# Epoch 54/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.9314 - mean_absolute_error: 37.9314 - val_loss: 39.4235 - val_mean_absolute_error: 39.4235
# Epoch 55/100
# 35/35 [==============================] - 0s 6ms/step - loss: 43.5402 - mean_absolute_error: 43.5402 - val_loss: 43.4418 - val_mean_absolute_error: 43.4418
# Epoch 56/100
# 35/35 [==============================] - 0s 8ms/step - loss: 42.8894 - mean_absolute_error: 42.8894 - val_loss: 41.5833 - val_mean_absolute_error: 41.5833
# Epoch 57/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.4203 - mean_absolute_error: 38.4203 - val_loss: 39.1717 - val_mean_absolute_error: 39.1717
# Epoch 58/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.3605 - mean_absolute_error: 38.3605 - val_loss: 39.0649 - val_mean_absolute_error: 39.0649
# Epoch 59/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.0349 - mean_absolute_error: 37.0349 - val_loss: 42.0136 - val_mean_absolute_error: 42.0136
# Epoch 60/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6381 - mean_absolute_error: 39.6381 - val_loss: 38.5486 - val_mean_absolute_error: 38.5486
# Epoch 61/100
# 35/35 [==============================] - 0s 5ms/step - loss: 37.3796 - mean_absolute_error: 37.3796 - val_loss: 39.4723 - val_mean_absolute_error: 39.4723
# Epoch 62/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.1127 - mean_absolute_error: 38.1127 - val_loss: 40.4851 - val_mean_absolute_error: 40.4851
# Epoch 63/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.9055 - mean_absolute_error: 38.9055 - val_loss: 39.2717 - val_mean_absolute_error: 39.2717
# Epoch 64/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.6750 - mean_absolute_error: 38.6750 - val_loss: 39.2802 - val_mean_absolute_error: 39.2802
# Epoch 65/100
# 35/35 [==============================] - 0s 8ms/step - loss: 39.5834 - mean_absolute_error: 39.5834 - val_loss: 42.2971 - val_mean_absolute_error: 42.2971
# Epoch 66/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.2354 - mean_absolute_error: 39.2354 - val_loss: 40.0529 - val_mean_absolute_error: 40.0529
# Epoch 67/100
# 35/35 [==============================] - 0s 9ms/step - loss: 37.3201 - mean_absolute_error: 37.3201 - val_loss: 38.4860 - val_mean_absolute_error: 38.4860
# Epoch 68/100
# 35/35 [==============================] - 0s 10ms/step - loss: 38.1896 - mean_absolute_error: 38.1896 - val_loss: 42.6442 - val_mean_absolute_error: 42.6442
# Epoch 69/100
# 35/35 [==============================] - 0s 8ms/step - loss: 39.8719 - mean_absolute_error: 39.8719 - val_loss: 39.3121 - val_mean_absolute_error: 39.3121
# Epoch 70/100
# 35/35 [==============================] - 0s 9ms/step - loss: 37.9261 - mean_absolute_error: 37.9261 - val_loss: 42.7532 - val_mean_absolute_error: 42.7532
# Epoch 71/100
# 35/35 [==============================] - 0s 6ms/step - loss: 39.7211 - mean_absolute_error: 39.7211 - val_loss: 41.1012 - val_mean_absolute_error: 41.1012
# Epoch 72/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.3430 - mean_absolute_error: 38.3430 - val_loss: 38.2360 - val_mean_absolute_error: 38.2360
# Epoch 73/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.2502 - mean_absolute_error: 37.2502 - val_loss: 42.4345 - val_mean_absolute_error: 42.4345
# Epoch 74/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.2936 - mean_absolute_error: 38.2936 - val_loss: 38.4654 - val_mean_absolute_error: 38.4654
# Epoch 75/100
# 35/35 [==============================] - 0s 6ms/step - loss: 36.5853 - mean_absolute_error: 36.5853 - val_loss: 42.5051 - val_mean_absolute_error: 42.5051
# Epoch 76/100
# 35/35 [==============================] - 0s 6ms/step - loss: 38.1974 - mean_absolute_error: 38.1974 - val_loss: 41.2901 - val_mean_absolute_error: 41.2901
# Epoch 77/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.8202 - mean_absolute_error: 37.8202 - val_loss: 39.0303 - val_mean_absolute_error: 39.0303
# Epoch 78/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.0108 - mean_absolute_error: 37.0108 - val_loss: 39.2710 - val_mean_absolute_error: 39.2710
# Epoch 79/100
# 35/35 [==============================] - 0s 6ms/step - loss: 37.1254 - mean_absolute_error: 37.1254 - val_loss: 39.1099 - val_mean_absolute_error: 39.1099
# Epoch 80/100
# 35/35 [==============================] - 0s 10ms/step - loss: 38.4990 - mean_absolute_error: 38.4990 - val_loss: 40.1696 - val_mean_absolute_error: 40.1696
# Epoch 81/100
# 35/35 [==============================] - 0s 7ms/step - loss: 36.9973 - mean_absolute_error: 36.9973 - val_loss: 41.7060 - val_mean_absolute_error: 41.7060
# Epoch 82/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.0124 - mean_absolute_error: 37.0124 - val_loss: 39.4256 - val_mean_absolute_error: 39.4256
# Epoch 83/100
# 35/35 [==============================] - 0s 7ms/step - loss: 38.4988 - mean_absolute_error: 38.4988 - val_loss: 38.5039 - val_mean_absolute_error: 38.5039
# Epoch 84/100
# 35/35 [==============================] - 0s 8ms/step - loss: 39.3905 - mean_absolute_error: 39.3905 - val_loss: 38.8184 - val_mean_absolute_error: 38.8184
# Epoch 85/100
# 35/35 [==============================] - 0s 9ms/step - loss: 37.1042 - mean_absolute_error: 37.1042 - val_loss: 38.4236 - val_mean_absolute_error: 38.4236
# Epoch 86/100
# 35/35 [==============================] - 0s 9ms/step - loss: 35.9659 - mean_absolute_error: 35.9659 - val_loss: 38.2675 - val_mean_absolute_error: 38.2675
# Epoch 87/100
# 35/35 [==============================] - 0s 8ms/step - loss: 38.3440 - mean_absolute_error: 38.3440 - val_loss: 40.3486 - val_mean_absolute_error: 40.3486
# Epoch 88/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.1083 - mean_absolute_error: 37.1083 - val_loss: 42.2151 - val_mean_absolute_error: 42.2151
# Epoch 89/100
# 35/35 [==============================] - 0s 7ms/step - loss: 36.5377 - mean_absolute_error: 36.5377 - val_loss: 38.9922 - val_mean_absolute_error: 38.9922
# Epoch 90/100
# 35/35 [==============================] - 0s 8ms/step - loss: 37.1259 - mean_absolute_error: 37.1259 - val_loss: 40.1544 - val_mean_absolute_error: 40.1544
# Epoch 91/100
# 35/35 [==============================] - 0s 7ms/step - loss: 36.5140 - mean_absolute_error: 36.5140 - val_loss: 38.4167 - val_mean_absolute_error: 38.4167
# Epoch 92/100
# 35/35 [==============================] - 0s 7ms/step - loss: 37.5183 - mean_absolute_error: 37.5183 - val_loss: 38.9832 - val_mean_absolute_error: 38.9832
# Epoch 93/100
# 35/35 [==============================] - 0s 8ms/step - loss: 38.1706 - mean_absolute_error: 38.1706 - val_loss: 40.0730 - val_mean_absolute_error: 40.0730
# Epoch 94/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.6574 - mean_absolute_error: 39.6574 - val_loss: 39.7860 - val_mean_absolute_error: 39.7860
# Epoch 95/100
# 35/35 [==============================] - 0s 5ms/step - loss: 38.9176 - mean_absolute_error: 38.9176 - val_loss: 50.9961 - val_mean_absolute_error: 50.9961
# Epoch 96/100
# 35/35 [==============================] - 0s 7ms/step - loss: 39.6276 - mean_absolute_error: 39.6276 - val_loss: 42.4283 - val_mean_absolute_error: 42.4283
# Epoch 97/100
# 35/35 [==============================] - 0s 5ms/step - loss: 39.2175 - mean_absolute_error: 39.2175 - val_loss: 39.8683 - val_mean_absolute_error: 39.8683
# Epoch 98/100
# 35/35 [==============================] - 0s 6ms/step - loss: 36.0321 - mean_absolute_error: 36.0321 - val_loss: 39.7693 - val_mean_absolute_error: 39.7693
# Epoch 99/100
# 35/35 [==============================] - 0s 6ms/step - loss: 36.7482 - mean_absolute_error: 36.7482 - val_loss: 38.7571 - val_mean_absolute_error: 38.7571
# Epoch 100/100
# 35/35 [==============================] - 0s 9ms/step - loss: 35.7200 - mean_absolute_error: 35.7200 - val_loss: 40.3910 - val_mean_absolute_error: 40.3910

# %%
prediction=NN_model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %%
y_test
# Out:
# 197    205.125000
# 188    264.916667
# 14     319.737500
# 31       1.916667
# 391    137.125000
#           ...
# 155     99.708333
# 392    197.083333
# 572    132.208333
# 307     38.416667
# 201    246.041667
# Name: PM 2.5, Length: 219, dtype: float64

# %%
sns.distplot(y_test.values.reshape(-1,1)-prediction)
plt.show()
# Out:
# C:\ProgramData\Anaconda3_2022.10\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,prediction)
plt.show()

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 41.43927536242992
# MSE: 3506.934057755504
# RMSE: 59.219372318148594

# %% [markdown]
# # Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 41.43927536242992
# MSE: 3506.934057755504
# RMSE: 59.219372318148594

# %%
import pickle 
# open a file, where you ant to store the data
file = open('ANN.pkl', 'wb')

# dump information to that file
pickle.dump(NN_model, file)

# %% [markdown]
# ### KNN Regressor model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor=KNeighborsRegressor(n_neighbors=1)
regressor.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 1.0

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: -0.08045200427243504

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# -0.12260548546487755

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3_2022.10\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM 2.5', ylabel='Density'>

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# ### Model Hyperparameter tuning

# %%
accuracy_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsRegressor(n_neighbors=i)
    score=cross_val_score(knn,X,y,cv=10,scoring="neg_mean_squared_error")
    accuracy_rate.append(score.mean())

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
#plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
 #        markerfacecolor='red', markersize=10)
plt.title('Accuracy Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy Rate')
# Out:
# Text(0, 0.5, 'Accuracy Rate')

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsRegressor(n_neighbors=1)

knn.fit(X_train,y_train)
predictions = knn.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\ProgramData\Anaconda3_2022.10\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM 2.5', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 57.635540334855406
# MSE: 7053.356899257989
# RMSE: 83.98426578388353

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsRegressor(n_neighbors=3)

knn.fit(X_train,y_train)
predictions = knn.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\ProgramData\Anaconda3_2022.10\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM 2.5', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 45.32886225266362
# MSE: 4232.47184930626
# RMSE: 65.05745037508203

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 57.635540334855406
# MSE: 7053.356899257989
# RMSE: 83.98426578388353

# %%
import pickle
# open a file, where you ant to store the data
file = open('KNN.pkl', 'wb')

# dump information to that file
pickle.dump(knn, file)
